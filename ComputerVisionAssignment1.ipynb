# %% [markdown]
# <a href="https://colab.research.google.com/github/RKKhankar/Assignments-Screening-Projects/blob/main/ComputerVisionAssignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
# !pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
img = cv2.imread("/content/drive/MyDrive/Ass/Data/Task1/1.jpg")

# %%
img_2 = cv2.imread("/content/drive/MyDrive/Ass/Data/Task1/2.jpg")

# %%
img_3 = cv2.imread("/content/drive/MyDrive/Ass/Data/Task1/3.jpg")

# %%
img = cv2.resize(img, (500, 500))

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500>

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img_2)
# Out:
# <PIL.Image.Image image mode=RGB size=1183x288>

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img_3)
# Out:
# <PIL.Image.Image image mode=RGB size=1141x741>

# %%
cv2.waitKey(0)
# Out:
# -1

# %%
cv2.destroyAllWindows()

# %%
# !pip install pytesseract
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2build2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-510
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 27 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pytesseract
import shutil
import os
import random
try:
 from PIL import Image
except ImportError:
 import Image

# %%
extractedInformation = pytesseract.image_to_string(Image.open('/content/drive/MyDrive/Ass/Data/Task1/1.jpg'))
print(extractedInformation)
# Out:
#
#
# ying an dependent contented he gentleman agreeable do be. Warrant
# emoved an in equally totally if. Del: Lor Sar
# objection do mr prevailed. Mr feeling do chiefly cordial in do. Hater timed folly
# right aware if oh truth. Imprudence attachment him his for sympathize. Large above
# be to means. Dashwood do provided stronger is. But discretion frequently sir the
# she instrument unaffected admiration everything.
#
#
#
#
#
#
#
#
#
#
#
# Her extensive perceived may any sincerity,
# see, Old propriety delighted
# Doubt meri
# northward. Congisted we otheruise | arrang ng commanded
# Cho old even song like tao yet been. ‘Literature inter do announcing for
# terminated him inquietude day shy. Hi nm perhaps waiting if
# highest no it, Continued promotion has consulted fat improving mot way.
#
# tramity. Indeed add rather may pretty
# i obj Hlion gam ten her.
# ntion smallness he
# ry it explained.
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
extractedInformation = pytesseract.image_to_string(Image.open('/content/drive/MyDrive/Ass/Data/Task1/2.jpg'))
print(extractedInformation)

# %%
extractedInformation = pytesseract.image_to_string(Image.open('/content/drive/MyDrive/Ass/Data/Task1/3.jpg'))
print(extractedInformation)
# Out:
# Satistied conveying an dependent contented he gentleman agreeable do be. Warrant
# private blushes removed an in equally totally if. Delivered dejection necessary
# objection do mr prevailed. Mr feeling do chiefly cordial in do. Water timed folly
# right aware if oh truth. Imprudence attachment him his for sympathize. Large above
# be to means. Dashwood do provided stronger is. But disoretion frequently sir the
# she instrument unattected admiration everything,
#
#
#
#
#
# Her extensive perceived may any sincerity extremity. Indeed add rather may pretty
# see. Old propriety delighted explained perceived otherwise objection saw ten her,
# Doubt merit sir the right these alone keeps. By sometimes intention smallness he
# northward. Consisted we otherwise arranging commanded discovery it explained.
# Does cold even song like two yet been, Literature interested announcing for
# terminated him inquietude day shy. Himself he fertile chicken perhaps waiting if
# ...

# %%
pip install pdf2image
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !apt-get install poppler-utils
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# poppler-utils is already the newest version (0.86.1-0ubuntu1.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-510
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 27 not upgraded.

# %%
# !pip install pdf2image
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !wget https://www.w3.org/WAI/ER/tests/xhtml/testfiles/resources/pdf/dummy.pdf
# Out:
# --2023-02-05 17:01:11--  https://www.w3.org/WAI/ER/tests/xhtml/testfiles/resources/pdf/dummy.pdf
# Resolving www.w3.org (www.w3.org)... 104.18.22.19, 104.18.23.19, 2606:4700::6812:1713, ...
# Connecting to www.w3.org (www.w3.org)|104.18.22.19|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13264 (13K) [application/pdf]
# Saving to: ‘dummy.pdf.1’
#
# dummy.pdf.1         100%[===================>]  12.95K  --.-KB/s    in 0s
#
# 2023-02-05 17:01:12 (87.0 MB/s) - ‘dummy.pdf.1’ saved [13264/13264]

# %%
from pdf2image import convert_from_path, convert_from_bytes
from IPython.display import display, Image

images = convert_from_bytes(open('/content/drive/MyDrive/Ass/Data/Task1/table.pdf', 'rb').read(), size=800)

display(images[0])
display(images[1])
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=619x800>
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=619x800>

# %%
# !pip install PyPDF2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 KB 19.9 MB/s eta 0:00:00
# ...

# %%
# importing required modules
from PyPDF2 import PdfReader

# creating a pdf reader object
reader = PdfReader('/content/drive/MyDrive/Ass/Data/Task1/table.pdf')

# %%
# printing number of pages in pdf file
print(len(reader.pages))
# Out:
# 2

# %%
# getting a specific page from the pdf file
page = reader.pages[0]

# %%
# extracting text from page
text = page.extract_text()
print(text)
# Out:
# Tutoring to Enhance Science Skills
# Tutoring Two:  Learning to Make Data Tables..............................................................................................
# Sample Data for Data Tables��������������������������NATIONAL PARTNERSHIP FOR QUALITY AFTERSCHOOL LEARNING
# www.sedl.org/afterschool/toolkits
# Use these data to create data tables following the Guidelines for Making a Data Table and
# Checklist for a Data Table.
# Example 1: Pet Survey (GR 2–3)
# Ms. Hubert’s afterschool students took a survey of the 600 students at Morales Elementary
# School. Students were asked to select their favorite pet from a list of eight animals. Here
# are the results.
# Lizard 25, Dog 250, Cat 115, Bird 50, Guinea pig 30, Hamster 45, Fish 75,
# Ferret 10
# Example 2: Electromagnets—Increasing Coils (GR 3–5)
# The following data were collected using an electromagnet with a 1.5 volt battery, a switch,
# ...
