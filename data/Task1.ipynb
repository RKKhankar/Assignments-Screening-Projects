# %% [markdown]
# ### Background
#
# A person’s creditworthiness is often associated (conversely) with the likelihood they may default on loans.
#
# We’re giving you anonymized data on about 1000 loan applications, along with a certain set of attributes about the applicant itself, and whether they were considered high risk.
#
# 0 = Low credit risk i.e high chance of paying back the loan amount #non defaulters
#
# 1 = High credit risk i.e low chance of paying back the loan amount #defaulter

# %% [markdown]
# ####  **Dataset Description**
#
#     The dataset has two files:
#
#     1. `applicant.csv`: This file contains personal data about the (primary) applicant
#     - Unique ID: `applicant_id` (string)
#     - Other fields:
#         - Primary_applicant_age_in_years (numeric)
#         - Gender (string)
#         - Marital_status (string)
#         - Number_of_dependents (numeric)
#         - Housing (string)
#         - Years_at_current_residence (numeric)
#         - Employment_status (string)
#         - Has_been_employed_for_at_least (string)
#         - Has_been_employed_for_at_most (string)
#         - Telephone (string)
#         - Foreign_worker (numeric)
#         - Savings_account_balance (string)
#         - Balance_in_existing_bank_account_(lower_limit_of_bucket) (string)
#         - Balance_in_existing_bank_account_(upper_limit_of_bucket) (string)
#
#     1. `loan.csv`: This file contains data more specific to the loan application
#     - Target: `high_risk_application` (numeric)
#     - Other fields:
#         - applicant_id (string)
#         - Months_loan_taken_for (numeric)
#         - Purpose (string)
#         - Principal_loan_amount (numeric)
#         - EMI_rate_in_percentage_of_disposable_income (numeric)
#         - Property (string)
#         - Has_coapplicant (numeric)
#         - Has_guarantor (numeric)
#         - Other_EMI_plans (string)
#         - Number_of_existing_loans_at_this_bank (numeric)
#         - Loan_history (string)

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
appdata = pd.read_csv('applicant.csv')

# %%
appdata.head()
# Out:
#    applicant_id  Primary_applicant_age_in_years  Gender  \
# 0       1469590                              67    male
# 1       1203873                              22  female
# 2       1432761                              49    male
# 3       1207582                              45    male
# 4       1674436                              53    male
#
#                Marital_status  Number_of_dependents   Housing  \
# 0                      single                     1       own
# 1  divorced/separated/married                     1       own
# 2                      single                     2       own
# 3                      single                     2  for free
# 4                      single                     2  for free
#
#    Years_at_current_residence            Employment_status  \
# 0                           4  skilled employee / official
# 1                           2  skilled employee / official
# 2                           3         unskilled - resident
# 3                           4  skilled employee / official
# 4                           4  skilled employee / official
#
#   Has_been_employed_for_at_least Has_been_employed_for_at_most  \
# 0                        7 years                           NaN
# 1                         1 year                       4 years
# 2                        4 years                       7 years
# 3                        4 years                       7 years
# 4                         1 year                       4 years
#
#                                Telephone  Foreign_worker  \
# 0  Registered under the applicant's name               1
# 1                                    NaN               1
# 2                                    NaN               1
# 3                                    NaN               1
# 4                                    NaN               1
#
#   Savings_account_balance  \
# 0                     NaN
# 1                     Low
# 2                     Low
# 3                     Low
# 4                     Low
#
#   Balance_in_existing_bank_account_(lower_limit_of_bucket)  \
# 0                                                NaN
# 1                                                  0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Balance_in_existing_bank_account_(upper_limit_of_bucket)
# 0                                                  0
# 1                                              2 lac
# 2                                                NaN
# 3                                                  0
# 4                                                  0

# %%
loan = pd.read_csv('loan.csv')

# %%
loan.head()
# Out:
#                     loan_application_id  applicant_id  Months_loan_taken_for  \
# 0  d68d975e-edad-11ea-8761-1d6f9c1ff461       1469590                      6
# 1  d68d989e-edad-11ea-b1d5-2bcf65006448       1203873                     48
# 2  d68d995c-edad-11ea-814a-1b6716782575       1432761                     12
# 3  d68d99fc-edad-11ea-8841-17e8848060ae       1207582                     42
# 4  d68d9a92-edad-11ea-9f3d-1f8682db006a       1674436                     24
#
#                 Purpose  Principal_loan_amount  \
# 0  electronic equipment                1169000
# 1  electronic equipment                5951000
# 2             education                2096000
# 3                  FF&E                7882000
# 4           new vehicle                4870000
#
#    EMI_rate_in_percentage_of_disposable_income  \
# 0                                            4
# 1                                            2
# 2                                            2
# 3                                            2
# 4                                            3
#
#                                             Property  Has_coapplicant  \
# 0                                        real estate                0
# 1                                        real estate                0
# 2                                        real estate                0
# 3  building society savings agreement/life insurance                0
# 4                                                NaN                0
#
#    Has_guarantor Other_EMI_plans  Number_of_existing_loans_at_this_bank  \
# 0              0             NaN                                      2
# 1              0             NaN                                      1
# 2              0             NaN                                      1
# 3              1             NaN                                      1
# 4              0             NaN                                      2
#
#                              Loan_history  high_risk_applicant
# 0   critical/pending loans at other banks                    0
# 1  existing loans paid back duly till now                    1
# 2   critical/pending loans at other banks                    0
# 3  existing loans paid back duly till now                    0
# 4   delay in paying off loans in the past                    1

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   loan_application_id                          1000 non-null   object
#  1   applicant_id                                 1000 non-null   int64
#  2   Months_loan_taken_for                        1000 non-null   int64
#  3   Purpose                                      988 non-null    object
#  4   Principal_loan_amount                        1000 non-null   int64
#  5   EMI_rate_in_percentage_of_disposable_income  1000 non-null   int64
#  6   Property                                     846 non-null    object
#  7   Has_coapplicant                              1000 non-null   int64
#  8   Has_guarantor                                1000 non-null   int64
#  9   Other_EMI_plans                              186 non-null    object
#  10  Number_of_existing_loans_at_this_bank        1000 non-null   int64
#  11  Loan_history                                 1000 non-null   object
#  12  high_risk_applicant                          1000 non-null   int64
# dtypes: int64(8), object(5)
# memory usage: 101.7+ KB

# %%
appdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   applicant_id                                              1000 non-null   int64
#  1   Primary_applicant_age_in_years                            1000 non-null   int64
#  2   Gender                                                    1000 non-null   object
#  3   Marital_status                                            1000 non-null   object
#  4   Number_of_dependents                                      1000 non-null   int64
#  5   Housing                                                   1000 non-null   object
#  6   Years_at_current_residence                                1000 non-null   int64
#  7   Employment_status                                         1000 non-null   object
#  8   Has_been_employed_for_at_least                            938 non-null    object
#  9   Has_been_employed_for_at_most                             747 non-null    object
#  10  Telephone                                                 404 non-null    object
#  11  Foreign_worker                                            1000 non-null   int64
#  12  Savings_account_balance                                   817 non-null    object
#  13  Balance_in_existing_bank_account_(lower_limit_of_bucket)  332 non-null    object
#  14  Balance_in_existing_bank_account_(upper_limit_of_bucket)  543 non-null    object
# dtypes: int64(5), object(10)
# memory usage: 117.3+ KB

# %%
loan.Other_EMI_plans.unique()
# Out:
# array([nan, 'bank', 'stores'], dtype=object)

# %%
loan.Purpose.unique()
# Out:
# array(['electronic equipment', 'education', 'FF&E', 'new vehicle',
#        'used vehicle', 'business', 'domestic appliances', 'repair costs',
#        nan, 'career development'], dtype=object)

# %%
loan.Property.unique()
# Out:
# array(['real estate', 'building society savings agreement/life insurance',
#        nan, 'car or other'], dtype=object)

# %% [markdown]
# #### **TASK-1**
#
# 1. Do the Exploratory Data Analysis & share the insights.
#
# 2. How would you segment customers based on their risk (of default).
# - We Can Segment Them As Follows :
# - 0 - Non-Defaulters : high chance of paying back the loan amount.
# - 1 - Defaulters : low chance of paying back the loan amount.
#
# 3. Which of these segments / sub-segments would you propose be approved?
#     - For e.g. Would a person with critical credit history be more creditworthy? Are young people more creditworthy? Would a person with more credit accounts be more creditworthy?
# 4. Tell us what your observations were on the data itself (completeness, skews).

# %%
data = pd.merge(appdata,loan)

# %%
data.head()
# Out:
#    applicant_id  Primary_applicant_age_in_years  Gender  \
# 0       1469590                              67    male
# 1       1203873                              22  female
# 2       1432761                              49    male
# 3       1207582                              45    male
# 4       1674436                              53    male
#
#                Marital_status  Number_of_dependents   Housing  \
# 0                      single                     1       own
# 1  divorced/separated/married                     1       own
# 2                      single                     2       own
# 3                      single                     2  for free
# 4                      single                     2  for free
#
#    Years_at_current_residence            Employment_status  \
# 0                           4  skilled employee / official
# 1                           2  skilled employee / official
# 2                           3         unskilled - resident
# 3                           4  skilled employee / official
# 4                           4  skilled employee / official
#
#   Has_been_employed_for_at_least Has_been_employed_for_at_most  ...  \
# 0                        7 years                           NaN  ...
# 1                         1 year                       4 years  ...
# 2                        4 years                       7 years  ...
# 3                        4 years                       7 years  ...
# 4                         1 year                       4 years  ...
#
#                 Purpose  Principal_loan_amount  \
# 0  electronic equipment                1169000
# 1  electronic equipment                5951000
# 2             education                2096000
# 3                  FF&E                7882000
# 4           new vehicle                4870000
#
#   EMI_rate_in_percentage_of_disposable_income  \
# 0                                           4
# 1                                           2
# 2                                           2
# 3                                           2
# 4                                           3
#
#                                             Property Has_coapplicant  \
# 0                                        real estate               0
# 1                                        real estate               0
# 2                                        real estate               0
# 3  building society savings agreement/life insurance               0
# 4                                                NaN               0
#
#   Has_guarantor  Other_EMI_plans Number_of_existing_loans_at_this_bank  \
# 0             0              NaN                                     2
# 1             0              NaN                                     1
# 2             0              NaN                                     1
# 3             1              NaN                                     1
# 4             0              NaN                                     2
#
#                              Loan_history  high_risk_applicant
# 0   critical/pending loans at other banks                    0
# 1  existing loans paid back duly till now                    1
# 2   critical/pending loans at other banks                    0
# 3  existing loans paid back duly till now                    0
# 4   delay in paying off loans in the past                    1
#
# [5 rows x 27 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 27 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   applicant_id                                              1000 non-null   int64
#  1   Primary_applicant_age_in_years                            1000 non-null   int64
#  2   Gender                                                    1000 non-null   object
#  3   Marital_status                                            1000 non-null   object
#  4   Number_of_dependents                                      1000 non-null   int64
#  5   Housing                                                   1000 non-null   object
#  6   Years_at_current_residence                                1000 non-null   int64
#  7   Employment_status                                         1000 non-null   object
#  8   Has_been_employed_for_at_least                            938 non-null    object
#  9   Has_been_employed_for_at_most                             747 non-null    object
#  10  Telephone                                                 404 non-null    object
#  11  Foreign_worker                                            1000 non-null   int64
#  12  Savings_account_balance                                   817 non-null    object
#  13  Balance_in_existing_bank_account_(lower_limit_of_bucket)  332 non-null    object
#  14  Balance_in_existing_bank_account_(upper_limit_of_bucket)  543 non-null    object
#  15  loan_application_id                                       1000 non-null   object
#  16  Months_loan_taken_for                                     1000 non-null   int64
#  17  Purpose                                                   988 non-null    object
#  18  Principal_loan_amount                                     1000 non-null   int64
#  19  EMI_rate_in_percentage_of_disposable_income               1000 non-null   int64
#  20  Property                                                  846 non-null    object
#  21  Has_coapplicant                                           1000 non-null   int64
#  22  Has_guarantor                                             1000 non-null   int64
#  23  Other_EMI_plans                                           186 non-null    object
#  24  Number_of_existing_loans_at_this_bank                     1000 non-null   int64
#  25  Loan_history                                              1000 non-null   object
#  26  high_risk_applicant                                       1000 non-null   int64
# dtypes: int64(12), object(15)
# memory usage: 218.8+ KB

# %%
data.duplicated().sum().any()
# Out:
# False

# %%
data.isnull().sum().any()
# Out:
# True

# %%
data.isnull().sum()
# Out:
# applicant_id                                                  0
# Primary_applicant_age_in_years                                0
# Gender                                                        0
# Marital_status                                                0
# Number_of_dependents                                          0
# Housing                                                       0
# Years_at_current_residence                                    0
# Employment_status                                             0
# Has_been_employed_for_at_least                               62
# Has_been_employed_for_at_most                               253
# Telephone                                                   596
# Foreign_worker                                                0
# Savings_account_balance                                     183
# Balance_in_existing_bank_account_(lower_limit_of_bucket)    668
# Balance_in_existing_bank_account_(upper_limit_of_bucket)    457
# loan_application_id                                           0
# Months_loan_taken_for                                         0
# Purpose                                                      12
# Principal_loan_amount                                         0
# EMI_rate_in_percentage_of_disposable_income                   0
# Property                                                    154
# Has_coapplicant                                               0
# Has_guarantor                                                 0
# Other_EMI_plans                                             814
# Number_of_existing_loans_at_this_bank                         0
# Loan_history                                                  0
# high_risk_applicant                                           0
# dtype: int64

# %% [markdown]
# #### Dropping The Columns Having Missing Values, As These Columns Doesn't Make Much Difference Even If We Remove Them.

# %%
data.drop(['Has_been_employed_for_at_least'], axis=1, inplace=True)

# %%
data.drop(['Has_been_employed_for_at_most'], axis=1, inplace=True)

# %%
data.drop(['Telephone'], axis=1, inplace=True)

# %%
data.drop(['Savings_account_balance','Balance_in_existing_bank_account_(lower_limit_of_bucket)'], axis=1, inplace=True)

# %%
data.drop(['Balance_in_existing_bank_account_(upper_limit_of_bucket)','Purpose','Property','Other_EMI_plans'], axis=1, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   applicant_id                                 1000 non-null   int64
#  1   Primary_applicant_age_in_years               1000 non-null   int64
#  2   Gender                                       1000 non-null   object
#  3   Marital_status                               1000 non-null   object
#  4   Number_of_dependents                         1000 non-null   int64
#  5   Housing                                      1000 non-null   object
#  6   Years_at_current_residence                   1000 non-null   int64
#  7   Employment_status                            1000 non-null   object
#  8   Foreign_worker                               1000 non-null   int64
#  9   loan_application_id                          1000 non-null   object
#  10  Months_loan_taken_for                        1000 non-null   int64
#  11  Principal_loan_amount                        1000 non-null   int64
#  12  EMI_rate_in_percentage_of_disposable_income  1000 non-null   int64
#  13  Has_coapplicant                              1000 non-null   int64
#  14  Has_guarantor                                1000 non-null   int64
#  15  Number_of_existing_loans_at_this_bank        1000 non-null   int64
#  16  Loan_history                                 1000 non-null   object
#  17  high_risk_applicant                          1000 non-null   int64
# dtypes: int64(12), object(6)
# memory usage: 148.4+ KB

# %%
data.head()
# Out:
#    applicant_id  Primary_applicant_age_in_years  Gender  \
# 0       1469590                              67    male
# 1       1203873                              22  female
# 2       1432761                              49    male
# 3       1207582                              45    male
# 4       1674436                              53    male
#
#                Marital_status  Number_of_dependents   Housing  \
# 0                      single                     1       own
# 1  divorced/separated/married                     1       own
# 2                      single                     2       own
# 3                      single                     2  for free
# 4                      single                     2  for free
#
#    Years_at_current_residence            Employment_status  Foreign_worker  \
# 0                           4  skilled employee / official               1
# 1                           2  skilled employee / official               1
# 2                           3         unskilled - resident               1
# 3                           4  skilled employee / official               1
# 4                           4  skilled employee / official               1
#
#                     loan_application_id  Months_loan_taken_for  \
# 0  d68d975e-edad-11ea-8761-1d6f9c1ff461                      6
# 1  d68d989e-edad-11ea-b1d5-2bcf65006448                     48
# 2  d68d995c-edad-11ea-814a-1b6716782575                     12
# 3  d68d99fc-edad-11ea-8841-17e8848060ae                     42
# 4  d68d9a92-edad-11ea-9f3d-1f8682db006a                     24
#
#    Principal_loan_amount  EMI_rate_in_percentage_of_disposable_income  \
# 0                1169000                                            4
# 1                5951000                                            2
# 2                2096000                                            2
# 3                7882000                                            2
# 4                4870000                                            3
#
#    Has_coapplicant  Has_guarantor  Number_of_existing_loans_at_this_bank  \
# 0                0              0                                      2
# 1                0              0                                      1
# 2                0              0                                      1
# 3                0              1                                      1
# 4                0              0                                      2
#
#                              Loan_history  high_risk_applicant
# 0   critical/pending loans at other banks                    0
# 1  existing loans paid back duly till now                    1
# 2   critical/pending loans at other banks                    0
# 3  existing loans paid back duly till now                    0
# 4   delay in paying off loans in the past                    1

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.histplot(data['Primary_applicant_age_in_years']);

# %%
data['Primary_applicant_age_in_years'].value_counts().sort_index(ascending=True)
# Out:
# 19     2
# 20    14
# 21    14
# 22    27
# 23    48
# 24    44
# 25    41
# 26    50
# 27    51
# 28    43
# 29    37
# 30    40
# 31    38
# 32    34
# 33    33
# 34    32
# 35    40
# 36    39
# 37    29
# 38    24
# 39    21
# 40    25
# 41    17
# 42    22
# 43    17
# 44    17
# 45    15
# 46    18
# 47    17
# 48    12
# 49    14
# 50    12
# 51     8
# 52     9
# 53     7
# 54    10
# 55     8
# 56     3
# 57     9
# 58     5
# 59     3
# 60     6
# 61     7
# 62     2
# 63     8
# 64     5
# 65     5
# 66     5
# 67     3
# 68     3
# 70     1
# 74     4
# 75     2
# Name: Primary_applicant_age_in_years, dtype: int64

# %% [markdown]
# - Applicants having 23 - 30 age are more in quantity as compared to others

# %%
sns.distplot(data.Primary_applicant_age_in_years.value_counts());

# %%
sns.distplot(data['Primary_applicant_age_in_years']);

# %%
data['high_risk_applicant'].groupby(data['Primary_applicant_age_in_years']).value_counts()
# Out:
# Primary_applicant_age_in_years  high_risk_applicant
# 19                              0                      1
#                                 1                      1
# 20                              0                      9
#                                 1                      5
# 21                              0                      9
#                                                       ..
# 68                              0                      1
# 70                              0                      1
# 74                              0                      3
#                                 1                      1
# 75                              0                      2
# Name: high_risk_applicant, Length: 100, dtype: int64

# %%
sns.countplot(data['Gender']);

# %%
data.Gender.value_counts()
# Out:
# male      690
# female    310
# Name: Gender, dtype: int64

# %%
data['high_risk_applicant'].groupby(data['Gender']).value_counts()
# Out:
# Gender  high_risk_applicant
# female  0                      201
#         1                      109
# male    0                      499
#         1                      191
# Name: high_risk_applicant, dtype: int64

# %%
data['high_risk_applicant'].groupby(data['Gender']).value_counts().plot(kind='pie');

# %%
data.Gender.value_counts().plot(kind='pie');

# %%
sns.distplot(data.Gender.value_counts());

# %% [markdown]
# - Total Female Applicants - 310 Out Of Which 209 are in non-defaulter zone: low risk (high chance of paying back the loan), 109 are in defaulter zone: high risk(low chance of paying back the loan)
#
# - Total male Applicants - 690 Out Of Which 499 are non-defaulter zone:low risk(high chance of paying back the loan), 191 are in defaulter zone: high risk(low chance of paying back the loan)

# %%
data['Marital_status'].unique()
# Out:
# array(['single', 'divorced/separated/married', 'divorced/separated',
#        'married/widowed'], dtype=object)

# %%
data.Marital_status.value_counts()
# Out:
# single                        548
# divorced/separated/married    310
# married/widowed                92
# divorced/separated             50
# Name: Marital_status, dtype: int64

# %%
data.Marital_status.value_counts().plot(kind='pie');

# %%
sns.countplot(data['Marital_status']);

# %%
data['high_risk_applicant'].groupby(data['Marital_status']).value_counts()
# Out:
# Marital_status              high_risk_applicant
# divorced/separated          0                       30
#                             1                       20
# divorced/separated/married  0                      201
#                             1                      109
# married/widowed             0                       67
#                             1                       25
# single                      0                      402
#                             1                      146
# Name: high_risk_applicant, dtype: int64

# %% [markdown]
# - single : Total = 548, Defaulter Zone = 146, Non-Defaulter Zone = 402
#
# - divorced/separated/married : Total = 310, Defaulter Zone = 109, Non-Defaulter Zone = 201
#
# - married/widowed : Total = 92, Defaulter Zone = 25, Non-Defaulter Zone = 67
#
# - divorced/separated : Total = 50, Defaulter Zone = 20, Non-Defaulter Zone = 30

# %%
548+310+92+50 #Total Applicants
# Out:
# 1000

# %%
146+109+25+20 #Defaulter Zone
# Out:
# 300

# %%
data['Number_of_dependents'].unique()
# Out:
# array([1, 2])

# %%
data.Number_of_dependents.value_counts()
# Out:
# 1    845
# 2    155
# Name: Number_of_dependents, dtype: int64

# %%
data.Number_of_dependents.value_counts().plot(kind='pie');

# %%
sns.countplot(data['Number_of_dependents']);

# %%
data['high_risk_applicant'].groupby(data['Number_of_dependents']).value_counts()
# Out:
# Number_of_dependents  high_risk_applicant
# 1                     0                      591
#                       1                      254
# 2                     0                      109
#                       1                       46
# Name: high_risk_applicant, dtype: int64

# %% [markdown]
# - People Having No. Of Dependents As 1 are 845 in Total Outoff Which 254 are in defaulter zone and 591 are in non-defaulter zone.
# - People Having No. Of Dependents As 2 are 155 in Total Outoff Which 46 are in defaulter zone and 109 are in non-defaulter zone

# %%
data['Housing'].unique()
# Out:
# array(['own', 'for free', 'rent'], dtype=object)

# %%
data.Housing.value_counts()
# Out:
# own         713
# rent        179
# for free    108
# Name: Housing, dtype: int64

# %%
data.Housing.value_counts().plot(kind='pie');

# %%
sns.countplot(data['Housing']);

# %%
data['high_risk_applicant'].groupby(data['Housing']).value_counts()
# Out:
# Housing   high_risk_applicant
# for free  0                       64
#           1                       44
# own       0                      527
#           1                      186
# rent      0                      109
#           1                       70
# Name: high_risk_applicant, dtype: int64

# %% [markdown]
# - Applicants Those Who Live In There "own" House are 713 in Total Out-off Which 186 are In Defaulter Zone & 527 are In Non-Defaulter Zone.
#
# - Applicants Those Who Live Giving "rent" For House are 179 in Total Out-off Which 70 are In Defaulter Zone & 109 are In Non-Defaulter Zone.
#
# - Applicants Those Who Live "for free" In House are 108 in Total Out-off Which 44 are In Defaulter Zone & 64 are In Non-Defaulter Zone.

# %%
data['Years_at_current_residence'].unique()
# Out:
# array([4, 2, 3, 1])

# %%
data.Years_at_current_residence.value_counts()
# Out:
# 4    413
# 2    308
# 3    149
# 1    130
# Name: Years_at_current_residence, dtype: int64

# %%
data.Years_at_current_residence.value_counts().plot(kind='pie');

# %%
sns.histplot(data['Years_at_current_residence']);

# %%
sns.distplot(data['Years_at_current_residence']);

# %%
data['high_risk_applicant'].groupby(data['Years_at_current_residence']).value_counts()
# Out:
# Years_at_current_residence  high_risk_applicant
# 1                           0                       94
#                             1                       36
# 2                           0                      211
#                             1                       97
# 3                           0                      106
#                             1                       43
# 4                           0                      289
#                             1                      124
# Name: high_risk_applicant, dtype: int64

# %% [markdown]
# ### Year At Current Residence :
# - Applicants Those Who Completed 4 Years At Current Residence Are 413 In Total, Out-off Which 124 are in Defaulter Zone, 289 are in Non-Defaulter Zone.
# - Applicants Those Who Completed 3 Years At Current Residence Are 149 In Total, Out-off Which 43 are in Defaulter Zone, 106 are in Non-Defaulter Zone.
# - Applicants Those Who Completed 2 Years At Current Residence Are 308 In Total, Out-off Which 97 are in Defaulter Zone, 211 are in Non-Defaulter Zone.
# - Applicants Those Who Completed 1 Years At Current Residence Are 130 In Total, Out-off Which 36 are in Defaulter Zone, 94 are in Non-Defaulter Zone.

# %%
data['Employment_status'].unique()
# Out:
# array(['skilled employee / official', 'unskilled - resident',
#        'management / self-employed / highly qualified employee / officer',
#        'unemployed / unskilled - non-resident'], dtype=object)

# %%
data.Employment_status.value_counts()
# Out:
# skilled employee / official                                         630
# unskilled - resident                                                200
# management / self-employed / highly qualified employee / officer    148
# unemployed / unskilled - non-resident                                22
# Name: Employment_status, dtype: int64

# %%
data.Employment_status.value_counts().plot(kind='pie');

# %%
data['high_risk_applicant'].groupby(data['Employment_status']).value_counts()
# Out:
# Employment_status                                                 high_risk_applicant
# management / self-employed / highly qualified employee / officer  0                       97
#                                                                   1                       51
# skilled employee / official                                       0                      444
#                                                                   1                      186
# unemployed / unskilled - non-resident                             0                       15
#                                                                   1                        7
# unskilled - resident                                              0                      144
#                                                                   1                       56
# Name: high_risk_applicant, dtype: int64

# %% [markdown]
# #### Employment_status
#
# - Applicants Those Who Are Marked as ''skilled employee / official'' Type Are  630 In Total Out-off Which 186 are In Defaulter Zone & 444 Are In Non-Defaulter Zone.
#
# - Applicants Those Who Are Marked as ''unskilled - resident'' Type Are  200 In Total Out-off Which 56 are In Defaulter Zone & 144 Are In Non-Defaulter Zone.
#
# - Applicants Those Who Are Marked as ''management / self-employed / highly qualified employee / officer'' Type Are 148 In Total Out-off Which 51 are In Defaulter Zone & 97 Are In Non-Defaulter Zone.
#
# - Applicants Those Who Are Marked as ''unemployed / unskilled - non-resident'' Type Are 22 In Total Out-off Which 7 are In Defaulter Zone & 15 Are In Non-Defaulter Zone.

# %%
data['Foreign_worker'].unique()
# Out:
# array([1, 0])

# %%
data.Foreign_worker.value_counts()
# Out:
# 1    963
# 0     37
# Name: Foreign_worker, dtype: int64

# %%
data.Foreign_worker.value_counts().plot(kind='pie');

# %%
sns.countplot(data['Foreign_worker']);

# %%
data['high_risk_applicant'].groupby(data['Foreign_worker']).value_counts()
# Out:
# Foreign_worker  high_risk_applicant
# 0               0                       33
#                 1                        4
# 1               0                      667
#                 1                      296
# Name: high_risk_applicant, dtype: int64

# %% [markdown]
# - 963 are Marked As Foreign Worker Out Of Which 296 Are In Defaulter Zone & 667 Are In Non-Defaulter Zone.
# - 37 are Not Marked As Foreign Worker Out Of Which 4 Are In Defaulter Zone & 33 Are In Non-Defaulter Zone.

# %%
data['Months_loan_taken_for'].unique()
# Out:
# array([ 6, 48, 12, 42, 24, 36, 30, 15,  9, 10,  7, 60, 18, 45, 11, 27,  8,
#        54, 20, 14, 33, 21, 16,  4, 47, 13, 22, 39, 28,  5, 26, 72, 40])

# %%
data.Months_loan_taken_for.value_counts()
# Out:
# 24    184
# 12    179
# 18    113
# 36     83
# 6      75
# 15     64
# 9      49
# 48     48
# 30     40
# 21     30
# 10     28
# 60     13
# 27     13
# 42     11
# 11      9
# 20      8
# 8       7
# 4       6
# 45      5
# 7       5
# 39      5
# 14      4
# 13      4
# 33      3
# 28      3
# 54      2
# 16      2
# 22      2
# 47      1
# 5       1
# 26      1
# 72      1
# 40      1
# Name: Months_loan_taken_for, dtype: int64

# %%
sns.histplot(data['Months_loan_taken_for']);

# %%
sns.distplot(data['Months_loan_taken_for']);

# %%
data['high_risk_applicant'].groupby(data['Months_loan_taken_for']).value_counts()
# Out:
# Months_loan_taken_for  high_risk_applicant
# 4                      0                        6
# 5                      0                        1
# 6                      0                       66
#                        1                        9
# 7                      0                        5
# 8                      0                        6
#                        1                        1
# 9                      0                       35
#                        1                       14
# 10                     0                       25
#                        1                        3
# 11                     0                        9
# 12                     0                      130
#                        1                       49
# 13                     0                        4
# 14                     0                        3
#                        1                        1
# 15                     0                       52
#                        1                       12
# 16                     0                        1
#                        1                        1
# 18                     0                       71
#                        1                       42
# 20                     0                        7
#                        1                        1
# 21                     0                       21
#                        1                        9
# 22                     0                        2
# 24                     0                      128
#                        1                       56
# 26                     0                        1
# 27                     0                        8
#                        1                        5
# 28                     0                        2
#                        1                        1
# 30                     0                       27
#                        1                       13
# 33                     0                        2
#                        1                        1
# 36                     0                       46
#                        1                       37
# 39                     0                        4
#                        1                        1
# 40                     1                        1
# 42                     0                        8
#                        1                        3
# 45                     1                        4
#                        0                        1
# 47                     0                        1
# 48                     1                       28
#                        0                       20
# 54                     0                        1
#                        1                        1
# 60                     0                        7
#                        1                        6
# 72                     1                        1
# Name: high_risk_applicant, dtype: int64

# %% [markdown]
# ### Months_loan_taken_for :
# - 184 applicants taken loan for 24 months which is the highest, out of which 56 are in Defaulter Zone & 128 are in Non-Defgaulter Zone.
# - 179 applicants taken loan for 12 months which is the 2nd highest, out of which 49 are in Defaulter Zone & 130 are in Non-Defgaulter Zone.
# - 113 applicants taken loan for 18 months which is the 3rd highest, out of which 42 are in Defaulter Zone & 71 are in Non-Defgaulter Zone.

# %%
sns.distplot(data['Principal_loan_amount']);

# %%
sns.histplot(data['Principal_loan_amount']);

# %%
data['high_risk_applicant'].groupby(data['Principal_loan_amount']).value_counts()
# Out:
# Principal_loan_amount  high_risk_applicant
# 250000                 0                      1
# 276000                 0                      1
# 338000                 0                      1
# 339000                 0                      1
# 343000                 0                      1
#                                              ..
# 15653000               0                      1
# 15672000               1                      1
# 15857000               0                      1
# 15945000               1                      1
# 18424000               1                      1
# Name: high_risk_applicant, Length: 949, dtype: int64

# %%
data.EMI_rate_in_percentage_of_disposable_income.value_counts()
# Out:
# 4    476
# 2    231
# 3    157
# 1    136
# Name: EMI_rate_in_percentage_of_disposable_income, dtype: int64

# %%
data.EMI_rate_in_percentage_of_disposable_income.value_counts().plot(kind='pie');

# %%
data['EMI_rate_in_percentage_of_disposable_income'].unique()
# Out:
# array([4, 2, 3, 1])

# %%
sns.histplot(data['EMI_rate_in_percentage_of_disposable_income']);

# %%
data['high_risk_applicant'].groupby(data['EMI_rate_in_percentage_of_disposable_income']).value_counts()
# Out:
# EMI_rate_in_percentage_of_disposable_income  high_risk_applicant
# 1                                            0                      102
#                                              1                       34
# 2                                            0                      169
#                                              1                       62
# 3                                            0                      112
#                                              1                       45
# 4                                            0                      317
#                                              1                      159
# Name: high_risk_applicant, dtype: int64

# %%
data.Has_coapplicant.unique()
# Out:
# array([0, 1])

# %%
data.Has_coapplicant.value_counts()
# Out:
# 0    959
# 1     41
# Name: Has_coapplicant, dtype: int64

# %%
data.Has_coapplicant.value_counts().plot(kind='pie');

# %%
sns.countplot(data['Has_coapplicant']);

# %%
data['high_risk_applicant'].groupby(data['Has_coapplicant']).value_counts()
# Out:
# Has_coapplicant  high_risk_applicant
# 0                0                      677
#                  1                      282
# 1                0                       23
#                  1                       18
# Name: high_risk_applicant, dtype: int64

# %% [markdown]
# - 959 People Has No Coapplicant Out-off Which 282 Are In Defaulter's Zone & 677 Are In Non-Defaulter's Zone.
# - 41 People Has Coapplicant Out-off Which 18 Are In Defaulter's Zone & 23 Are In Non-Defaulter's Zone.

# %%
data.Has_guarantor.value_counts()
# Out:
# 0    948
# 1     52
# Name: Has_guarantor, dtype: int64

# %%
data.Has_guarantor.value_counts().plot(kind='pie');

# %%
sns.countplot(data['Has_guarantor']);

# %%
data['high_risk_applicant'].groupby(data['Has_guarantor']).value_counts()
# Out:
# Has_guarantor  high_risk_applicant
# 0              0                      658
#                1                      290
# 1              0                       42
#                1                       10
# Name: high_risk_applicant, dtype: int64

# %% [markdown]
# ####
# - 948 People Has No Guarantor Out-off Which 290 Are In Defaulter's Zone & 658 Are In Non-Defaulter's Zone.
# - 52 People Has Guarantor Out-off Which 10 Are In Defaulter's Zone & 42 Are In Non-Defaulter's Zone.

# %%
data['Number_of_existing_loans_at_this_bank'].unique()
# Out:
# array([2, 1, 3, 4])

# %%
data.Number_of_existing_loans_at_this_bank.value_counts()
# Out:
# 1    633
# 2    333
# 3     28
# 4      6
# Name: Number_of_existing_loans_at_this_bank, dtype: int64

# %%
data.Number_of_existing_loans_at_this_bank.value_counts().plot(kind='pie');

# %%
sns.countplot(data['Number_of_existing_loans_at_this_bank']);

# %%
data['high_risk_applicant'].groupby(data['Number_of_existing_loans_at_this_bank']).value_counts()
# Out:
# Number_of_existing_loans_at_this_bank  high_risk_applicant
# 1                                      0                      433
#                                        1                      200
# 2                                      0                      241
#                                        1                       92
# 3                                      0                       22
#                                        1                        6
# 4                                      0                        4
#                                        1                        2
# Name: high_risk_applicant, dtype: int64

# %% [markdown]
# #### Number_of_existing_loans_at_this_bank:
#
# - 633 Applicants Having 1 Number Of Loan At This Bank Out Of Which 200 Are In Defaulters Zone, 433 Are In Non-Defaulters Zone.
# - 333 Applicants Having 2 Number Of Loans At This Bank Out Of Which 92 Are In Defaulters Zone, 241 Are In Non-Defaulters Zone.
# - 28 Applicants Having 3 Number Of Loans At This Bank Out Of Which 6 Are In Defaulters Zone, 22 Are In Non-Defaulters Zone.
# - 6 Applicants Having 4 Number Of Loans At This Bank Out Of Which 2 Are In Defaulters Zone, 4 Are In Non-Defaulters Zone.

# %%
data['Loan_history'].unique()
# Out:
# array(['critical/pending loans at other banks',
#        'existing loans paid back duly till now',
#        'delay in paying off loans in the past',
#        'no loans taken/all loans paid back duly',
#        'all loans at this bank paid back duly'], dtype=object)

# %%
data['Loan_history'].value_counts()
# Out:
# existing loans paid back duly till now     530
# critical/pending loans at other banks      293
# delay in paying off loans in the past       88
# all loans at this bank paid back duly       49
# no loans taken/all loans paid back duly     40
# Name: Loan_history, dtype: int64

# %%
data.Loan_history.value_counts().plot(kind='pie');

# %%
sns.distplot(data.Loan_history.value_counts());

# %%
sns.countplot(data['Loan_history']);

# %%
data['high_risk_applicant'].groupby(data['Loan_history']).value_counts()
# Out:
# Loan_history                             high_risk_applicant
# all loans at this bank paid back duly    1                       28
#                                          0                       21
# critical/pending loans at other banks    0                      243
#                                          1                       50
# delay in paying off loans in the past    0                       60
#                                          1                       28
# existing loans paid back duly till now   0                      361
#                                          1                      169
# no loans taken/all loans paid back duly  1                       25
#                                          0                       15
# Name: high_risk_applicant, dtype: int64

# %% [markdown]
# #### Loan_history
#
# - all loans at this bank paid back duly : Total : 49, Non-Defaulter's Zone : 21, Defaulter's Zone : 28
#
# - critical/pending loans at other banks : Total : 293, Non-Defaulter's Zone : 243, Defaulter's Zone : 50
#
# - delay in paying off loans in the past : Total : 88, Non-Defaulter's Zone : 60, Defaulter's Zone : 28
#
# - existing loans paid back duly till now : Total : 530, Non-Defaulter's Zone : 361, Defaulter's Zone : 169
#
# - no loans taken/all loans paid back duly : Total : 40, Non-Defaulter's Zone : 15, Defaulter's Zone : 25

# %%
sns.countplot(data['high_risk_applicant']);

# %%
sns.distplot(data.high_risk_applicant.value_counts());

# %%
data.high_risk_applicant.value_counts()
# Out:
# 0    700
# 1    300
# Name: high_risk_applicant, dtype: int64

# %%
data.high_risk_applicant.value_counts().plot(kind='pie');

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   applicant_id                                 1000 non-null   int64
#  1   Primary_applicant_age_in_years               1000 non-null   int64
#  2   Gender                                       1000 non-null   object
#  3   Marital_status                               1000 non-null   object
#  4   Number_of_dependents                         1000 non-null   int64
#  5   Housing                                      1000 non-null   object
#  6   Years_at_current_residence                   1000 non-null   int64
#  7   Employment_status                            1000 non-null   object
#  8   Foreign_worker                               1000 non-null   int64
#  9   loan_application_id                          1000 non-null   object
#  10  Months_loan_taken_for                        1000 non-null   int64
#  11  Principal_loan_amount                        1000 non-null   int64
#  12  EMI_rate_in_percentage_of_disposable_income  1000 non-null   int64
#  13  Has_coapplicant                              1000 non-null   int64
#  14  Has_guarantor                                1000 non-null   int64
#  15  Number_of_existing_loans_at_this_bank        1000 non-null   int64
#  16  Loan_history                                 1000 non-null   object
#  17  high_risk_applicant                          1000 non-null   int64
# dtypes: int64(12), object(6)
# memory usage: 180.7+ KB

# %% [markdown]
# #### Applying Label Encoder For Categorical Variables

# %%
from sklearn.preprocessing import LabelEncoder

# %%
Le = LabelEncoder()

data['Gender'] = Le.fit_transform(data['Gender'])

data['Marital_status'] = Le.fit_transform(data['Marital_status'])

data['Housing'] = Le.fit_transform(data['Housing'])

data['Employment_status'] = Le.fit_transform(data['Employment_status'])

data['Loan_history'] = Le.fit_transform(data['Loan_history'])

# %%
data['applicant_id'] = Le.fit_transform(data['applicant_id'])
data['loan_application_id'] = Le.fit_transform(data['loan_application_id'])

# %%
data.head()
# Out:
#    applicant_id  Primary_applicant_age_in_years  Gender  Marital_status  \
# 0           436                              67       1               3
# 1           115                              22       0               1
# 2           380                              49       1               3
# 3           117                              45       1               3
# 4           713                              53       1               3
#
#    Number_of_dependents  Housing  Years_at_current_residence  \
# 0                     1        1                           4
# 1                     1        1                           2
# 2                     2        1                           3
# 3                     2        0                           4
# 4                     2        0                           4
#
#    Employment_status  Foreign_worker  loan_application_id  \
# 0                  1               1                    0
# 1                  1               1                    1
# 2                  3               1                    2
# 3                  1               1                    3
# 4                  1               1                    4
#
#    Months_loan_taken_for  Principal_loan_amount  \
# 0                      6                1169000
# 1                     48                5951000
# 2                     12                2096000
# 3                     42                7882000
# 4                     24                4870000
#
#    EMI_rate_in_percentage_of_disposable_income  Has_coapplicant  \
# 0                                            4                0
# 1                                            2                0
# 2                                            2                0
# 3                                            2                0
# 4                                            3                0
#
#    Has_guarantor  Number_of_existing_loans_at_this_bank  Loan_history  \
# 0              0                                      2             1
# 1              0                                      1             3
# 2              0                                      1             1
# 3              1                                      1             3
# 4              0                                      2             2
#
#    high_risk_applicant
# 0                    0
# 1                    1
# 2                    0
# 3                    0
# 4                    1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   applicant_id                                 1000 non-null   int64
#  1   Primary_applicant_age_in_years               1000 non-null   int64
#  2   Gender                                       1000 non-null   int64
#  3   Marital_status                               1000 non-null   int64
#  4   Number_of_dependents                         1000 non-null   int64
#  5   Housing                                      1000 non-null   int64
#  6   Years_at_current_residence                   1000 non-null   int64
#  7   Employment_status                            1000 non-null   int64
#  8   Foreign_worker                               1000 non-null   int64
#  9   loan_application_id                          1000 non-null   int64
#  10  Months_loan_taken_for                        1000 non-null   int64
#  11  Principal_loan_amount                        1000 non-null   int64
#  12  EMI_rate_in_percentage_of_disposable_income  1000 non-null   int64
#  13  Has_coapplicant                              1000 non-null   int64
#  14  Has_guarantor                                1000 non-null   int64
#  15  Number_of_existing_loans_at_this_bank        1000 non-null   int64
#  16  Loan_history                                 1000 non-null   int64
#  17  high_risk_applicant                          1000 non-null   int64
# dtypes: int64(18)
# memory usage: 180.7 KB

# %%
sns.pairplot(data)

# %% [markdown]
# #### Would a person with critical credit history be more creditworthy?

# %%
data['high_risk_applicant'].groupby(data['Loan_history']).value_counts()
# Out:
# Loan_history  high_risk_applicant
# 0             1                       28
#               0                       21
# 1             0                      243
#               1                       50
# 2             0                       60
#               1                       28
# 3             0                      361
#               1                      169
# 4             1                       25
#               0                       15
# Name: high_risk_applicant, dtype: int64

# %% [markdown]
# #### Loan_history
#
# - all loans at this bank paid back duly : Total : 49, Non-Defaulter's Zone : 21, Defaulter's Zone : 28
#
# - critical/pending loans at other banks : Total : 293, Non-Defaulter's Zone : 243, Defaulter's Zone : 50
#
# - delay in paying off loans in the past : Total : 88, Non-Defaulter's Zone : 60, Defaulter's Zone : 28
#
# - existing loans paid back duly till now : Total : 530, Non-Defaulter's Zone : 361, Defaulter's Zone : 169
#
# - no loans taken/all loans paid back duly : Total : 40, Non-Defaulter's Zone : 15, Defaulter's Zone : 25

# %% [markdown]
# #### According To Data We Can Assume That A Person With Critical Credit History Can Be More Creditworthy As Out-off 293 Only 50 Are In Defaulter's Zone, as Compared To Others It Seems To Be More Creditworthy.

# %% [markdown]
# #### Are young people more creditworthy?
#
# - Applicants having 23 - 30 age are more in quantity as compared to others

# %%
data['high_risk_applicant'].groupby(data['Primary_applicant_age_in_years']<30).value_counts()
# Out:
# Primary_applicant_age_in_years  high_risk_applicant
# False                           0                      466
#                                 1                      163
# True                            0                      234
#                                 1                      137
# Name: high_risk_applicant, dtype: int64

# %%
data['high_risk_applicant'].groupby(data['Primary_applicant_age_in_years']>30).value_counts()
# Out:
# Primary_applicant_age_in_years  high_risk_applicant
# False                           0                      263
#                                 1                      148
# True                            0                      437
#                                 1                      152
# Name: high_risk_applicant, dtype: int64

# %%
data['high_risk_applicant'].groupby(data['Primary_applicant_age_in_years']==23).value_counts()
# Out:
# Primary_applicant_age_in_years  high_risk_applicant
# False                           0                      672
#                                 1                      280
# True                            0                       28
#                                 1                       20
# Name: high_risk_applicant, dtype: int64

# %% [markdown]
# #### We can consider young people more creditworthy taking there quantity in consideration as compared to others.

# %%
sns.distplot(data['high_risk_applicant'].groupby(data['Primary_applicant_age_in_years']).value_counts());

# %%
sns.distplot(data['Primary_applicant_age_in_years']);

# %%
data[["high_risk_applicant", "Primary_applicant_age_in_years"]].corr()
# Out:
#                                 high_risk_applicant  \
# high_risk_applicant                        1.000000
# Primary_applicant_age_in_years            -0.091127
#
#                                 Primary_applicant_age_in_years
# high_risk_applicant                                  -0.091127
# Primary_applicant_age_in_years                        1.000000

# %%
sns.regplot(x=data['Primary_applicant_age_in_years'], y=data['high_risk_applicant']);

# %% [markdown]
# ####  Would a person with more credit accounts be more creditworthy?

# %%
data['high_risk_applicant'].groupby(data['Number_of_existing_loans_at_this_bank']).value_counts()
# Out:
# Number_of_existing_loans_at_this_bank  high_risk_applicant
# 1                                      0                      433
#                                        1                      200
# 2                                      0                      241
#                                        1                       92
# 3                                      0                       22
#                                        1                        6
# 4                                      0                        4
#                                        1                        2
# Name: high_risk_applicant, dtype: int64

# %%
200/(200+433)
# Out:
# 0.315955766192733

# %%
92/(241+92)
# Out:
# 0.27627627627627627

# %%
6/(6+22)
# Out:
# 0.21428571428571427

# %%
2/(4+2)
# Out:
# 0.3333333333333333

# %% [markdown]
# #### Number_of_existing_loans_at_this_bank:
#
# - 633 Applicants Having 1 Number Of Loan At This Bank Out Of Which 200 Are In Defaulters Zone, 433 Are In Non-Defaulters Zone.
# - 333 Applicants Having 2 Number Of Loans At This Bank Out Of Which 92 Are In Defaulters Zone, 241 Are In Non-Defaulters Zone.
# - 28 Applicants Having 3 Number Of Loans At This Bank Out Of Which 6 Are In Defaulters Zone, 22 Are In Non-Defaulters Zone.
# - 6 Applicants Having 4 Number Of Loans At This Bank Out Of Which 2 Are In Defaulters Zone, 4 Are In Non-Defaulters Zone.

# %% [markdown]
# #### We can assume  a person with more credit accounts be more creditworthy according to the current scenario, but we can't be 100 % sure as we just have 1000 entries out of which only 6 applicants have 4 number of loans at this bank out of which 2 are in defaulter's zone and 4 are in non-defaulter's zone.

# %%
sns.distplot(data)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
data.head(2)
# Out:
#    applicant_id  Primary_applicant_age_in_years  Gender  Marital_status  \
# 0           436                              67       1               3
# 1           115                              22       0               1
#
#    Number_of_dependents  Housing  Years_at_current_residence  \
# 0                     1        1                           4
# 1                     1        1                           2
#
#    Employment_status  Foreign_worker  loan_application_id  \
# 0                  1               1                    0
# 1                  1               1                    1
#
#    Months_loan_taken_for  Principal_loan_amount  \
# 0                      6                1169000
# 1                     48                5951000
#
#    EMI_rate_in_percentage_of_disposable_income  Has_coapplicant  \
# 0                                            4                0
# 1                                            2                0
#
#    Has_guarantor  Number_of_existing_loans_at_this_bank  Loan_history  \
# 0              0                                      2             1
# 1              0                                      1             3
#
#    high_risk_applicant
# 0                    0
# 1                    1

# %%
plt.figure(figsize=(15,5))
sns.distplot(data['Primary_applicant_age_in_years']);

# %%
plt.figure(figsize=(15,5))
sns.distplot(data['Gender']);

# %%
plt.figure(figsize=(15,5))
sns.distplot(data['Marital_status']);

# %%
plt.figure(figsize=(15,5))
sns.distplot(data['Number_of_dependents']);

# %%
plt.figure(figsize=(15,5))
sns.distplot(data['Housing']);

# %%
plt.figure(figsize=(15,5))
sns.distplot(data['Years_at_current_residence']);

# %%
plt.figure(figsize=(15,5))
sns.distplot(data['Employment_status']);

# %%
plt.figure(figsize=(15,5))
sns.distplot(data['Foreign_worker']);

# %%
plt.figure(figsize=(15,5))
sns.distplot(data['Months_loan_taken_for']);

# %%
plt.figure(figsize=(15,5))
sns.distplot(data['Principal_loan_amount']);

# %%
plt.figure(figsize=(15,5))
sns.distplot(data['Number_of_existing_loans_at_this_bank']);

# %%
data.head(1)
# Out:
#    applicant_id  Primary_applicant_age_in_years  Gender  Marital_status  \
# 0           436                              67       1               3
#
#    Number_of_dependents  Housing  Years_at_current_residence  \
# 0                     1        1                           4
#
#    Employment_status  Foreign_worker  loan_application_id  \
# 0                  1               1                    0
#
#    Months_loan_taken_for  Principal_loan_amount  \
# 0                      6                1169000
#
#    EMI_rate_in_percentage_of_disposable_income  Has_coapplicant  \
# 0                                            4                0
#
#    Has_guarantor  Number_of_existing_loans_at_this_bank  Loan_history  \
# 0              0                                      2             1
#
#    high_risk_applicant
# 0                    0

# %%
data['high_risk_applicant'].groupby(data['Gender']).value_counts()
# Out:
# Gender  high_risk_applicant
# 0       0                      201
#         1                      109
# 1       0                      499
#         1                      191
# Name: high_risk_applicant, dtype: int64

# %%
109/310
# Out:
# 0.35161290322580646

# %%
191/690
# Out:
# 0.2768115942028985

# %%
data[['Primary_applicant_age_in_years','Gender','Marital_status','Number_of_dependents','Housing','Years_at_current_residence','Employment_status','Foreign_worker','Months_loan_taken_for','Principal_loan_amount','EMI_rate_in_percentage_of_disposable_income','Has_coapplicant','Has_guarantor','Number_of_existing_loans_at_this_bank','Loan_history','high_risk_applicant']].corr()
# Out:
#                                              Primary_applicant_age_in_years  \
# Primary_applicant_age_in_years                                     1.000000
# Gender                                                             0.161694
# Marital_status                                                     0.147954
# Number_of_dependents                                               0.118201
# Housing                                                           -0.301419
# Years_at_current_residence                                         0.266419
# Employment_status                                                 -0.001637
# Foreign_worker                                                     0.006151
# Months_loan_taken_for                                             -0.036136
# Principal_loan_amount                                              0.032716
# EMI_rate_in_percentage_of_disposable_income                        0.058266
# Has_coapplicant                                                   -0.018357
# Has_guarantor                                                     -0.023923
# Number_of_existing_loans_at_this_bank                              0.149254
# Loan_history                                                      -0.157261
# high_risk_applicant                                               -0.091127
#
#                                                Gender  Marital_status  \
# Primary_applicant_age_in_years               0.161694        0.147954
# Gender                                       1.000000        0.748342
# Marital_status                               0.748342        1.000000
# Number_of_dependents                         0.203431        0.256475
# Housing                                     -0.219844       -0.225034
# Years_at_current_residence                  -0.013818        0.041256
# Employment_status                           -0.041278       -0.025732
# Foreign_worker                              -0.051202       -0.046226
# Months_loan_taken_for                        0.081432        0.093721
# Principal_loan_amount                        0.093482        0.102481
# EMI_rate_in_percentage_of_disposable_income  0.086302        0.138389
# Has_coapplicant                              0.007742        0.026430
# Has_guarantor                                0.010907        0.016897
# Number_of_existing_loans_at_this_bank        0.094260        0.111867
# Loan_history                                -0.059183       -0.083229
# high_risk_applicant                         -0.075493       -0.095055
#
#                                              Number_of_dependents   Housing  \
# Primary_applicant_age_in_years                           0.118201 -0.301419
# Gender                                                   0.203431 -0.219844
# Marital_status                                           0.256475 -0.225034
# Number_of_dependents                                     1.000000 -0.114508
# Housing                                                 -0.114508  1.000000
# Years_at_current_residence                               0.042643 -0.011941
# Employment_status                                        0.127146  0.106596
# Foreign_worker                                          -0.077071 -0.063582
# Months_loan_taken_for                                   -0.023834 -0.157049
# Principal_loan_amount                                    0.017142 -0.135632
# EMI_rate_in_percentage_of_disposable_income             -0.071207 -0.089405
# Has_coapplicant                                         -0.032817  0.038835
# Has_guarantor                                            0.036589  0.053505
# Number_of_existing_loans_at_this_bank                    0.109667 -0.048591
# Loan_history                                            -0.070008  0.084026
# high_risk_applicant                                     -0.003015  0.019315
#
#                                              Years_at_current_residence  \
# Primary_applicant_age_in_years                                 0.266419
# Gender                                                        -0.013818
# Marital_status                                                 0.041256
# Number_of_dependents                                           0.042643
# Housing                                                       -0.011941
# Years_at_current_residence                                     1.000000
# Employment_status                                              0.000450
# Foreign_worker                                                 0.054097
# Months_loan_taken_for                                          0.034067
# Principal_loan_amount                                          0.028926
# EMI_rate_in_percentage_of_disposable_income                    0.049302
# Has_coapplicant                                                0.001623
# Has_guarantor                                                 -0.028334
# Number_of_existing_loans_at_this_bank                          0.089625
# Loan_history                                                  -0.086987
# high_risk_applicant                                            0.002967
#
#                                              Employment_status  \
# Primary_applicant_age_in_years                       -0.001637
# Gender                                               -0.041278
# Marital_status                                       -0.025732
# Number_of_dependents                                  0.127146
# Housing                                               0.106596
# Years_at_current_residence                            0.000450
# Employment_status                                     1.000000
# Foreign_worker                                       -0.100028
# Months_loan_taken_for                                -0.215438
# Principal_loan_amount                                -0.261139
# EMI_rate_in_percentage_of_disposable_income          -0.078090
# Has_coapplicant                                      -0.027902
# Has_guarantor                                         0.079757
# Number_of_existing_loans_at_this_bank                 0.004544
# Loan_history                                         -0.013921
# high_risk_applicant                                  -0.032756
#
#                                              Foreign_worker  \
# Primary_applicant_age_in_years                     0.006151
# Gender                                            -0.051202
# Marital_status                                    -0.046226
# Number_of_dependents                              -0.077071
# Housing                                           -0.063582
# Years_at_current_residence                         0.054097
# Employment_status                                 -0.100028
# Foreign_worker                                     1.000000
# Months_loan_taken_for                              0.138196
# Principal_loan_amount                              0.050050
# EMI_rate_in_percentage_of_disposable_income        0.090024
# Has_coapplicant                                   -0.066338
# Has_guarantor                                     -0.097256
# Number_of_existing_loans_at_this_bank              0.009717
# Loan_history                                       0.000513
# high_risk_applicant                                0.082079
#
#                                              Months_loan_taken_for  \
# Primary_applicant_age_in_years                           -0.036136
# Gender                                                    0.081432
# Marital_status                                            0.093721
# Number_of_dependents                                     -0.023834
# Housing                                                  -0.157049
# Years_at_current_residence                                0.034067
# Employment_status                                        -0.215438
# Foreign_worker                                            0.138196
# Months_loan_taken_for                                     1.000000
# Principal_loan_amount                                     0.624984
# EMI_rate_in_percentage_of_disposable_income               0.074749
# Has_coapplicant                                           0.029698
# Has_guarantor                                            -0.039594
# Number_of_existing_loans_at_this_bank                    -0.011284
# Loan_history                                              0.029430
# high_risk_applicant                                       0.214927
#
#                                              Principal_loan_amount  \
# Primary_applicant_age_in_years                            0.032716
# Gender                                                    0.093482
# Marital_status                                            0.102481
# Number_of_dependents                                      0.017142
# Housing                                                  -0.135632
# Years_at_current_residence                                0.028926
# Employment_status                                        -0.261139
# Foreign_worker                                            0.050050
# Months_loan_taken_for                                     0.624984
# Principal_loan_amount                                     1.000000
# EMI_rate_in_percentage_of_disposable_income              -0.271316
# Has_coapplicant                                           0.079076
# Has_guarantor                                            -0.065237
# Number_of_existing_loans_at_this_bank                     0.020795
# Loan_history                                              0.029050
# high_risk_applicant                                       0.154739
#
#                                              EMI_rate_in_percentage_of_disposable_income  \
# Primary_applicant_age_in_years                                                  0.058266
# Gender                                                                          0.086302
# Marital_status                                                                  0.138389
# Number_of_dependents                                                           -0.071207
# Housing                                                                        -0.089405
# Years_at_current_residence                                                      0.049302
# Employment_status                                                              -0.078090
# Foreign_worker                                                                  0.090024
# Months_loan_taken_for                                                           0.074749
# Principal_loan_amount                                                          -0.271316
# EMI_rate_in_percentage_of_disposable_income                                     1.000000
# Has_coapplicant                                                                -0.013048
# Has_guarantor                                                                  -0.006429
# Number_of_existing_loans_at_this_bank                                           0.021669
# Loan_history                                                                   -0.059779
# high_risk_applicant                                                             0.072404
#
#                                              Has_coapplicant  Has_guarantor  \
# Primary_applicant_age_in_years                     -0.018357      -0.023923
# Gender                                              0.007742       0.010907
# Marital_status                                      0.026430       0.016897
# Number_of_dependents                               -0.032817       0.036589
# Housing                                             0.038835       0.053505
# Years_at_current_residence                          0.001623      -0.028334
# Employment_status                                  -0.027902       0.079757
# Foreign_worker                                     -0.066338      -0.097256
# Months_loan_taken_for                               0.029698      -0.039594
# Principal_loan_amount                               0.079076      -0.065237
# EMI_rate_in_percentage_of_disposable_income        -0.013048      -0.006429
# Has_coapplicant                                     1.000000      -0.048426
# Has_guarantor                                      -0.048426       1.000000
# Number_of_existing_loans_at_this_bank              -0.006001      -0.024682
# Loan_history                                       -0.018868       0.011062
# high_risk_applicant                                 0.062728      -0.055039
#
#                                              Number_of_existing_loans_at_this_bank  \
# Primary_applicant_age_in_years                                            0.149254
# Gender                                                                    0.094260
# Marital_status                                                            0.111867
# Number_of_dependents                                                      0.109667
# Housing                                                                  -0.048591
# Years_at_current_residence                                                0.089625
# Employment_status                                                         0.004544
# Foreign_worker                                                            0.009717
# Months_loan_taken_for                                                    -0.011284
# Principal_loan_amount                                                     0.020795
# EMI_rate_in_percentage_of_disposable_income                               0.021669
# Has_coapplicant                                                          -0.006001
# Has_guarantor                                                            -0.024682
# Number_of_existing_loans_at_this_bank                                     1.000000
# Loan_history                                                             -0.387820
# high_risk_applicant                                                      -0.045732
#
#                                              Loan_history  high_risk_applicant
# Primary_applicant_age_in_years                  -0.157261            -0.091127
# Gender                                          -0.059183            -0.075493
# Marital_status                                  -0.083229            -0.095055
# Number_of_dependents                            -0.070008            -0.003015
# Housing                                          0.084026             0.019315
# Years_at_current_residence                      -0.086987             0.002967
# Employment_status                               -0.013921            -0.032756
# Foreign_worker                                   0.000513             0.082079
# Months_loan_taken_for                            0.029430             0.214927
# Principal_loan_amount                            0.029050             0.154739
# EMI_rate_in_percentage_of_disposable_income     -0.059779             0.072404
# Has_coapplicant                                 -0.018868             0.062728
# Has_guarantor                                    0.011062            -0.055039
# Number_of_existing_loans_at_this_bank           -0.387820            -0.045732
# Loan_history                                     1.000000             0.097054
# high_risk_applicant                              0.097054             1.000000

# %%
data[['Primary_applicant_age_in_years','Gender','Marital_status','Number_of_dependents','Housing','Years_at_current_residence','Employment_status','Foreign_worker','Months_loan_taken_for','Principal_loan_amount','EMI_rate_in_percentage_of_disposable_income','Has_coapplicant','Has_guarantor','Number_of_existing_loans_at_this_bank','Loan_history','high_risk_applicant']].corr()
# Out:
#                                              Primary_applicant_age_in_years  \
# Primary_applicant_age_in_years                                     1.000000
# Gender                                                             0.161694
# Marital_status                                                     0.147954
# Number_of_dependents                                               0.118201
# Housing                                                           -0.301419
# Years_at_current_residence                                         0.266419
# Employment_status                                                 -0.001637
# Foreign_worker                                                     0.006151
# Months_loan_taken_for                                             -0.036136
# Principal_loan_amount                                              0.032716
# EMI_rate_in_percentage_of_disposable_income                        0.058266
# Has_coapplicant                                                   -0.018357
# Has_guarantor                                                     -0.023923
# Number_of_existing_loans_at_this_bank                              0.149254
# Loan_history                                                      -0.157261
# high_risk_applicant                                               -0.091127
#
#                                                Gender  Marital_status  \
# Primary_applicant_age_in_years               0.161694        0.147954
# Gender                                       1.000000        0.748342
# Marital_status                               0.748342        1.000000
# Number_of_dependents                         0.203431        0.256475
# Housing                                     -0.219844       -0.225034
# Years_at_current_residence                  -0.013818        0.041256
# Employment_status                           -0.041278       -0.025732
# Foreign_worker                              -0.051202       -0.046226
# Months_loan_taken_for                        0.081432        0.093721
# Principal_loan_amount                        0.093482        0.102481
# EMI_rate_in_percentage_of_disposable_income  0.086302        0.138389
# Has_coapplicant                              0.007742        0.026430
# Has_guarantor                                0.010907        0.016897
# Number_of_existing_loans_at_this_bank        0.094260        0.111867
# Loan_history                                -0.059183       -0.083229
# high_risk_applicant                         -0.075493       -0.095055
#
#                                              Number_of_dependents   Housing  \
# Primary_applicant_age_in_years                           0.118201 -0.301419
# Gender                                                   0.203431 -0.219844
# Marital_status                                           0.256475 -0.225034
# Number_of_dependents                                     1.000000 -0.114508
# Housing                                                 -0.114508  1.000000
# Years_at_current_residence                               0.042643 -0.011941
# Employment_status                                        0.127146  0.106596
# Foreign_worker                                          -0.077071 -0.063582
# Months_loan_taken_for                                   -0.023834 -0.157049
# Principal_loan_amount                                    0.017142 -0.135632
# EMI_rate_in_percentage_of_disposable_income             -0.071207 -0.089405
# Has_coapplicant                                         -0.032817  0.038835
# Has_guarantor                                            0.036589  0.053505
# Number_of_existing_loans_at_this_bank                    0.109667 -0.048591
# Loan_history                                            -0.070008  0.084026
# high_risk_applicant                                     -0.003015  0.019315
#
#                                              Years_at_current_residence  \
# Primary_applicant_age_in_years                                 0.266419
# Gender                                                        -0.013818
# Marital_status                                                 0.041256
# Number_of_dependents                                           0.042643
# Housing                                                       -0.011941
# Years_at_current_residence                                     1.000000
# Employment_status                                              0.000450
# Foreign_worker                                                 0.054097
# Months_loan_taken_for                                          0.034067
# Principal_loan_amount                                          0.028926
# EMI_rate_in_percentage_of_disposable_income                    0.049302
# Has_coapplicant                                                0.001623
# Has_guarantor                                                 -0.028334
# Number_of_existing_loans_at_this_bank                          0.089625
# Loan_history                                                  -0.086987
# high_risk_applicant                                            0.002967
#
#                                              Employment_status  \
# Primary_applicant_age_in_years                       -0.001637
# Gender                                               -0.041278
# Marital_status                                       -0.025732
# Number_of_dependents                                  0.127146
# Housing                                               0.106596
# Years_at_current_residence                            0.000450
# Employment_status                                     1.000000
# Foreign_worker                                       -0.100028
# Months_loan_taken_for                                -0.215438
# Principal_loan_amount                                -0.261139
# EMI_rate_in_percentage_of_disposable_income          -0.078090
# Has_coapplicant                                      -0.027902
# Has_guarantor                                         0.079757
# Number_of_existing_loans_at_this_bank                 0.004544
# Loan_history                                         -0.013921
# high_risk_applicant                                  -0.032756
#
#                                              Foreign_worker  \
# Primary_applicant_age_in_years                     0.006151
# Gender                                            -0.051202
# Marital_status                                    -0.046226
# Number_of_dependents                              -0.077071
# Housing                                           -0.063582
# Years_at_current_residence                         0.054097
# Employment_status                                 -0.100028
# Foreign_worker                                     1.000000
# Months_loan_taken_for                              0.138196
# Principal_loan_amount                              0.050050
# EMI_rate_in_percentage_of_disposable_income        0.090024
# Has_coapplicant                                   -0.066338
# Has_guarantor                                     -0.097256
# Number_of_existing_loans_at_this_bank              0.009717
# Loan_history                                       0.000513
# high_risk_applicant                                0.082079
#
#                                              Months_loan_taken_for  \
# Primary_applicant_age_in_years                           -0.036136
# Gender                                                    0.081432
# Marital_status                                            0.093721
# Number_of_dependents                                     -0.023834
# Housing                                                  -0.157049
# Years_at_current_residence                                0.034067
# Employment_status                                        -0.215438
# Foreign_worker                                            0.138196
# Months_loan_taken_for                                     1.000000
# Principal_loan_amount                                     0.624984
# EMI_rate_in_percentage_of_disposable_income               0.074749
# Has_coapplicant                                           0.029698
# Has_guarantor                                            -0.039594
# Number_of_existing_loans_at_this_bank                    -0.011284
# Loan_history                                              0.029430
# high_risk_applicant                                       0.214927
#
#                                              Principal_loan_amount  \
# Primary_applicant_age_in_years                            0.032716
# Gender                                                    0.093482
# Marital_status                                            0.102481
# Number_of_dependents                                      0.017142
# Housing                                                  -0.135632
# Years_at_current_residence                                0.028926
# Employment_status                                        -0.261139
# Foreign_worker                                            0.050050
# Months_loan_taken_for                                     0.624984
# Principal_loan_amount                                     1.000000
# EMI_rate_in_percentage_of_disposable_income              -0.271316
# Has_coapplicant                                           0.079076
# Has_guarantor                                            -0.065237
# Number_of_existing_loans_at_this_bank                     0.020795
# Loan_history                                              0.029050
# high_risk_applicant                                       0.154739
#
#                                              EMI_rate_in_percentage_of_disposable_income  \
# Primary_applicant_age_in_years                                                  0.058266
# Gender                                                                          0.086302
# Marital_status                                                                  0.138389
# Number_of_dependents                                                           -0.071207
# Housing                                                                        -0.089405
# Years_at_current_residence                                                      0.049302
# Employment_status                                                              -0.078090
# Foreign_worker                                                                  0.090024
# Months_loan_taken_for                                                           0.074749
# Principal_loan_amount                                                          -0.271316
# EMI_rate_in_percentage_of_disposable_income                                     1.000000
# Has_coapplicant                                                                -0.013048
# Has_guarantor                                                                  -0.006429
# Number_of_existing_loans_at_this_bank                                           0.021669
# Loan_history                                                                   -0.059779
# high_risk_applicant                                                             0.072404
#
#                                              Has_coapplicant  Has_guarantor  \
# Primary_applicant_age_in_years                     -0.018357      -0.023923
# Gender                                              0.007742       0.010907
# Marital_status                                      0.026430       0.016897
# Number_of_dependents                               -0.032817       0.036589
# Housing                                             0.038835       0.053505
# Years_at_current_residence                          0.001623      -0.028334
# Employment_status                                  -0.027902       0.079757
# Foreign_worker                                     -0.066338      -0.097256
# Months_loan_taken_for                               0.029698      -0.039594
# Principal_loan_amount                               0.079076      -0.065237
# EMI_rate_in_percentage_of_disposable_income        -0.013048      -0.006429
# Has_coapplicant                                     1.000000      -0.048426
# Has_guarantor                                      -0.048426       1.000000
# Number_of_existing_loans_at_this_bank              -0.006001      -0.024682
# Loan_history                                       -0.018868       0.011062
# high_risk_applicant                                 0.062728      -0.055039
#
#                                              Number_of_existing_loans_at_this_bank  \
# Primary_applicant_age_in_years                                            0.149254
# Gender                                                                    0.094260
# Marital_status                                                            0.111867
# Number_of_dependents                                                      0.109667
# Housing                                                                  -0.048591
# Years_at_current_residence                                                0.089625
# Employment_status                                                         0.004544
# Foreign_worker                                                            0.009717
# Months_loan_taken_for                                                    -0.011284
# Principal_loan_amount                                                     0.020795
# EMI_rate_in_percentage_of_disposable_income                               0.021669
# Has_coapplicant                                                          -0.006001
# Has_guarantor                                                            -0.024682
# Number_of_existing_loans_at_this_bank                                     1.000000
# Loan_history                                                             -0.387820
# high_risk_applicant                                                      -0.045732
#
#                                              Loan_history  high_risk_applicant
# Primary_applicant_age_in_years                  -0.157261            -0.091127
# Gender                                          -0.059183            -0.075493
# Marital_status                                  -0.083229            -0.095055
# Number_of_dependents                            -0.070008            -0.003015
# Housing                                          0.084026             0.019315
# Years_at_current_residence                      -0.086987             0.002967
# Employment_status                               -0.013921            -0.032756
# Foreign_worker                                   0.000513             0.082079
# Months_loan_taken_for                            0.029430             0.214927
# Principal_loan_amount                            0.029050             0.154739
# EMI_rate_in_percentage_of_disposable_income     -0.059779             0.072404
# Has_coapplicant                                 -0.018868             0.062728
# Has_guarantor                                    0.011062            -0.055039
# Number_of_existing_loans_at_this_bank           -0.387820            -0.045732
# Loan_history                                     1.000000             0.097054
# high_risk_applicant                              0.097054             1.000000

# %%
plt.figure(figsize=(17,7))
sns.heatmap(data[['Primary_applicant_age_in_years','Gender','Marital_status','Number_of_dependents','Housing','Years_at_current_residence','Employment_status','Foreign_worker','Months_loan_taken_for','Principal_loan_amount','EMI_rate_in_percentage_of_disposable_income','Has_coapplicant','Has_guarantor','Number_of_existing_loans_at_this_bank','Loan_history','high_risk_applicant']].corr(), annot=True)
plt.show()

# %%
data.to_csv('data2')

# %% [markdown]
# ### **TASK-2**
#
# **Develop the ML model(s) to predict the credit risk(low or high) for a given applicant.**
#
# **Business Constraint:** Note that it is worse to state an applicant as a low credit risk when they are actually a high risk(Type2) - False Negative , than it is to state an applicant to be a high credit risk when they aren’t(Type1) - False Positive.

# %%
data.drop(['loan_application_id','applicant_id','Marital_status','Number_of_dependents','Housing','Years_at_current_residence','Foreign_worker','Principal_loan_amount','EMI_rate_in_percentage_of_disposable_income','Has_coapplicant','Has_guarantor'], axis=1, inplace=True)

# %%
data.head(2)
# Out:
#    Primary_applicant_age_in_years  Gender  Employment_status  \
# 0                              67       1                  1
# 1                              22       0                  1
#
#    Months_loan_taken_for  Number_of_existing_loans_at_this_bank  Loan_history  \
# 0                      6                                      2             1
# 1                     48                                      1             3
#
#    high_risk_applicant
# 0                    0
# 1                    1

# %%
X = data.loc[:, data.columns != 'high_risk_applicant' ] # independent variable

y = data.loc[:, data.columns == 'high_risk_applicant'] #target variable

# %%
X = pd.get_dummies(X, drop_first=True)

# %%
X.head()
# Out:
#    Primary_applicant_age_in_years  Gender  Employment_status  \
# 0                              67       1                  1
# 1                              22       0                  1
# 2                              49       1                  3
# 3                              45       1                  1
# 4                              53       1                  1
#
#    Months_loan_taken_for  Number_of_existing_loans_at_this_bank  Loan_history
# 0                      6                                      2             1
# 1                     48                                      1             3
# 2                     12                                      1             1
# 3                     42                                      1             3
# 4                     24                                      2             2

# %%
y.head()
# Out:
#    high_risk_applicant
# 0                    0
# 1                    1
# 2                    0
# 3                    0
# 4                    1

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LogisticRegression

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=12)

# %%
X_train.head()
# Out:
#      Primary_applicant_age_in_years  Gender  Employment_status  \
# 834                              25       0                  3
# 227                              53       1                  0
# 471                              23       0                  1
# 929                              43       1                  3
# 457                              35       1                  1
#
#      Months_loan_taken_for  Number_of_existing_loans_at_this_bank  \
# 834                     15                                      1
# 227                     12                                      1
# 471                      6                                      1
# 929                     12                                      2
# 457                     12                                      1
#
#      Loan_history
# 834             3
# 227             3
# 471             3
# 929             2
# 457             3

# %%
X_test.head()
# Out:
#      Primary_applicant_age_in_years  Gender  Employment_status  \
# 518                              43       1                  1
# 871                              46       1                  1
# 797                              22       0                  3
# 274                              34       1                  3
# 325                              39       1                  3
#
#      Months_loan_taken_for  Number_of_existing_loans_at_this_bank  \
# 518                      6                                      1
# 871                      6                                      2
# 797                     12                                      2
# 274                     30                                      1
# 325                      8                                      2
#
#      Loan_history
# 518             3
# 871             1
# 797             1
# 274             3
# 325             1

# %%
X_train.shape,X_test.shape
# Out:
# ((700, 6), (300, 6))

# %%
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = logreg.predict(X_test)
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(X_test, y_test)))
# Out:
# Accuracy of logistic regression classifier on test set: 0.70

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, y_pred)

# %%
confusion_matrix
# Out:
# array([[198,   4],
#        [ 87,  11]])

# %%
sns.heatmap(confusion_matrix)
# Out:
# <AxesSubplot:>

# %%
TN = 198
FP = 87
FN = 4
TP = 11

# %%
TPR = 11/(11+4) #TPR = TP/P
TPR
# Out:
# 0.7333333333333333

# %%
TNR = 198/(198+87) #TNR = TN/N
TNR
# Out:
# 0.6947368421052632

# %%
FPR = 87/(198+87) #FPR = FP/N 
FPR
# Out:
# 0.30526315789473685

# %%
FNR = 4/(11+4) #FNR = FN/p
FNR
# Out:
# 0.26666666666666666

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.98      0.81       202
#            1       0.73      0.11      0.19        98
#
#     accuracy                           0.70       300
#    macro avg       0.71      0.55      0.50       300
# weighted avg       0.71      0.70      0.61       300
